# %%
import os

base_path = "dataset"

folders = [
    "water_leakage",
    "waterlogging",
    "drain_overflow",
    "overflowing_bin",
    "trash_pile",
    "construction_waste"
]

for folder in folders:
    os.makedirs(os.path.join(base_path, folder), exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %%
os.listdir("dataset")
# Out:
# ['construction_waste',
#  'drain_overflow',
#  'overflowing_bin',
#  'trash_pile',
#  'waterlogging',
#  'water_leakage']

# %%
# !python -m pip install icrawler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    -------------------- ------------------- 1/2 [icrawler]
#    -------------------- ------------------- 1/2 [icrawler]
#    -------------------- ------------------- 1/2 [icrawler]
#    -------------------- ------------------- 1/2 [icrawler]
#    -------------------- ------------------- 1/2 [icrawler]
#    -------------------- ------------------- 1/2 [icrawler]
#    -------------------- ------------------- 1/2 [icrawler]
#    ---------------------------------------- 2/2 [icrawler]
#
# ...

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/water_leakage'}
)

crawler.crawl(
    keyword='water pipe leakage street india',
    max_num=80
)
# Out:
# 2026-02-18 19:39:11,180 - INFO - icrawler.crawler - start crawling...
# 2026-02-18 19:39:11,182 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-18 19:39:11,184 - INFO - feeder - thread feeder-001 exit
# 2026-02-18 19:39:11,188 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-18 19:39:11,195 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-18 19:39:12,044 - INFO - parser - parsing result page https://www.bing.com/images/async?q=water pipe leakage street india&first=0
# 2026-02-18 19:39:15,084 - INFO - downloader - image #1	https://static.toiimg.com/thumb/msid-74820179,width-1070,height-580,imgsize-5465178,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg
# 2026-02-18 19:39:16,753 - INFO - downloader - image #2	https://static.toiimg.com/thumb/msid-63723443,width-1070,height-580,imgsize-1190605,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg
# ...

# %%
import os
len(os.listdir("dataset/water_leakage"))
# Out:
# 59

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/waterlogging'}
)

crawler.crawl(
    keyword='waterlogging road india monsoon',
    max_num=120
)
# Out:
# 2026-02-18 19:42:21,066 - INFO - icrawler.crawler - start crawling...
# 2026-02-18 19:42:21,069 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-18 19:42:21,072 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-18 19:42:21,076 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-18 19:42:21,080 - INFO - feeder - thread feeder-001 exit
# 2026-02-18 19:42:21,588 - INFO - parser - parsing result page https://www.bing.com/images/async?q=waterlogging road india monsoon&first=0
# 2026-02-18 19:42:21,911 - INFO - downloader - image #1	https://assets.telegraphindia.com/telegraph/2022/Jun/1656585326_delhiii-rainnnn.jpg
# 2026-02-18 19:42:22,322 - INFO - downloader - image #2	https://im.indiatimes.in/content/2022/Jun/FWe8A64VsAAxLib_62bd5758b125e.jpg
# 2026-02-18 19:42:22,818 - INFO - downloader - image #3	https://www.shutterstock.com/image-photo/water-logging-during-monsoon-on-260nw-2201775939.jpg
# ...

# %%
import os
len(os.listdir("dataset/waterlogging"))
# Out:
# 65

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/drain_overflow'}
)

crawler.crawl(
    keyword='sewage drain overflow street india',
    max_num=120
)
# Out:
# 2026-02-18 20:01:45,448 - INFO - icrawler.crawler - start crawling...
# 2026-02-18 20:01:45,453 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-18 20:01:45,455 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-18 20:01:45,459 - INFO - feeder - thread feeder-001 exit
# 2026-02-18 20:01:45,464 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-18 20:01:45,977 - INFO - parser - parsing result page https://www.bing.com/images/async?q=sewage drain overflow street india&first=0
# 2026-02-18 20:01:46,142 - INFO - downloader - image #1	https://static.toiimg.com/thumb/msid-87878627,width-1070,height-580,imgsize-28492,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg
# 2026-02-18 20:01:48,077 - INFO - downloader - image #2	https://static.toiimg.com/thumb/msid-74568252,width-1070,height-580,imgsize-3105540,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg
# ...

# %%
import os
len(os.listdir("dataset/drain_overflow"))
# Out:
# 72

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/overflowing_bin'}
)

crawler.crawl(
    keyword='overflowing garbage bin street india',
    max_num=120
)
# Out:
# 2026-02-18 20:03:53,103 - INFO - icrawler.crawler - start crawling...
# 2026-02-18 20:03:53,105 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-18 20:03:53,108 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-18 20:03:53,113 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-18 20:03:53,114 - INFO - feeder - thread feeder-001 exit
# 2026-02-18 20:03:53,764 - INFO - parser - parsing result page https://www.bing.com/images/async?q=overflowing garbage bin street india&first=0
# 2026-02-18 20:03:54,711 - INFO - downloader - image #1	https://thumbs.dreamstime.com/z/waste-bin-overflowing-garbage-street-pile-299555536.jpg
# 2026-02-18 20:03:55,216 - INFO - downloader - image #2	https://c8.alamy.com/comp/2WH9BAK/overflowing-garbage-bin-on-a-street-in-toronto-2WH9BAK.jpg
# ...

# %%
import os
len(os.listdir("dataset/overflowing_bin"))
# Out:
# 65

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/trash_pile'}
)

crawler.crawl(
    keyword='garbage pile roadside india illegal dumping',
    max_num=120
)
# Out:
# 2026-02-18 20:05:34,349 - INFO - icrawler.crawler - start crawling...
# 2026-02-18 20:05:34,350 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-18 20:05:34,355 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-18 20:05:34,358 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-18 20:05:34,358 - INFO - feeder - thread feeder-001 exit
# 2026-02-18 20:05:34,832 - INFO - parser - parsing result page https://www.bing.com/images/async?q=garbage pile roadside india illegal dumping&first=0
# 2026-02-18 20:05:36,619 - INFO - downloader - image #1	https://img.freepik.com/premium-photo/illegal-garbage-dumping-roadside-environmental-concern_956920-66545.jpg
# 2026-02-18 20:05:38,684 - INFO - downloader - image #2	https://img.freepik.com/premium-photo/illegal-garbage-dumping-roadside-environmental-concern_956920-66514.jpg
# ...

# %%
import os
len(os.listdir("dataset/trash_pile"))
# Out:
# 70

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/construction_waste'}
)

crawler.crawl(
    keyword='construction debris dumped roadside india',
    max_num=120
)
# Out:
# 2026-02-18 20:08:04,361 - INFO - icrawler.crawler - start crawling...
# 2026-02-18 20:08:04,364 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-18 20:08:04,369 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-18 20:08:04,372 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-18 20:08:04,372 - INFO - feeder - thread feeder-001 exit
# 2026-02-18 20:08:04,952 - INFO - parser - parsing result page https://www.bing.com/images/async?q=construction debris dumped roadside india&first=0
# 2026-02-18 20:08:05,490 - INFO - downloader - image #1	https://c8.alamy.com/comp/2R20ET0/roadside-dumping-of-construction-debris-and-rubbish-2R20ET0.jpg
# 2026-02-18 20:08:06,278 - INFO - downloader - image #2	https://static.toiimg.com/thumb/msid-62345004,width-1070,height-580,imgsize-437646,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg
# ...

# %%
import os
len(os.listdir("dataset/construction_waste"))
# Out:
# 64

# %%
pip install split-folders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts split-folders.exe, split_folders.exe and splitfolders.exe are installed in 'C:\Users\dishi\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import splitfolders

splitfolders.ratio(
    "dataset",
    output="dataset_split",
    seed=42,
    ratio=(0.8, 0.2)
)
# Out:
# Copying files: 395 files [00:00, 514.91 files/s]

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
IMG_SIZE = 224
BATCH_SIZE = 32
NUM_CLASSES = 12
train_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset_split/train",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset_split/val",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# 2026-02-24 09:41:42,957 - INFO - numexpr.utils - NumExpr defaulting to 12 threads.
# Found 315 files belonging to 6 classes.
# Found 80 files belonging to 6 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(6, activation='softmax')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=12
)
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.1968 - loss: 2.1068 - val_accuracy: 0.2875 - val_loss: 1.7270
# Epoch 2/12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 588ms/step - accuracy: 0.2635 - loss: 1.7866 - val_accuracy: 0.2750 - val_loss: 1.6649
# Epoch 3/12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 664ms/step - accuracy: 0.3238 - loss: 1.5750 - val_accuracy: 0.3625 - val_loss: 1.6337
# Epoch 4/12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 676ms/step - accuracy: 0.4127 - loss: 1.4686 - val_accuracy: 0.3250 - val_loss: 1.6371
# Epoch 5/12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 536ms/step - accuracy: 0.4349 - loss: 1.4204 - val_accuracy: 0.3500 - val_loss: 1.6137
# Epoch 6/12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 530ms/step - accuracy: 0.4762 - loss: 1.3724 - val_accuracy: 0.3375 - val_loss: 1.5696
# Epoch 7/12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 661ms/step - accuracy: 0.5111 - loss: 1.2953 - val_accuracy: 0.3250 - val_loss: 1.5631
# Epoch 8/12
# ...

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/broken_electric_pole'}
)

crawler.crawl(
    keyword='broken electric pole india',
    max_num=120
)
# Out:
# 2026-02-24 09:18:54,261 - INFO - icrawler.crawler - start crawling...
# 2026-02-24 09:18:54,263 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-24 09:18:54,266 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-24 09:18:54,269 - INFO - feeder - thread feeder-001 exit
# 2026-02-24 09:18:54,273 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-24 09:18:55,374 - INFO - parser - parsing result page https://www.bing.com/images/async?q=broken electric pole india&first=0
# 2026-02-24 09:18:56,365 - INFO - downloader - image #1	https://static.toiimg.com/thumb/msid-70425729,width-1070,height-580,imgsize-4495252,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg
# 2026-02-24 09:18:57,571 - INFO - downloader - image #2	https://thumbs.dreamstime.com/b/broken-electric-pole-lamp-254096875.jpg
# 2026-02-24 09:18:58,414 - INFO - downloader - image #3	https://c8.alamy.com/comp/C4XFY6/detail-of-electric-pole-india-C4XFY6.jpg
# ...

# %%
crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/exposed_wires'}
)

crawler.crawl(
    keyword='exposed electric wires street india',
    max_num=120
)
# Out:
# 2026-02-24 09:20:41,405 - INFO - icrawler.crawler - start crawling...
# 2026-02-24 09:20:41,406 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-24 09:20:41,410 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-24 09:20:41,414 - INFO - feeder - thread feeder-001 exit
# 2026-02-24 09:20:41,419 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-24 09:20:43,488 - INFO - parser - parsing result page https://www.bing.com/images/async?q=exposed electric wires street india&first=0
# 2026-02-24 09:20:48,029 - INFO - downloader - image #1	https://image.shutterstock.com/z/stock-photo-out-of-focus-messy-electrical-cables-in-india-uncovered-optical-fiber-technology-open-air-261982511.jpg
# 2026-02-24 09:20:50,463 - INFO - downloader - image #2	https://thumbs.dreamstime.com/z/intertwining-electric-power-cables-bangkok-thailand-electric-power-wires-street-bangkok-109093056.jpg
# ...

# %%
crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/streetlight_issue'}
)

crawler.crawl(
    keyword='street light not working india night',
    max_num=120
)
# Out:
# 2026-02-24 09:22:29,286 - INFO - icrawler.crawler - start crawling...
# 2026-02-24 09:22:29,290 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-24 09:22:29,294 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-24 09:22:29,299 - INFO - feeder - thread feeder-001 exit
# 2026-02-24 09:22:29,302 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-24 09:22:29,971 - INFO - parser - parsing result page https://www.bing.com/images/async?q=street light not working india night&first=0
# 2026-02-24 09:22:30,840 - INFO - downloader - image #1	https://static.toiimg.com/thumb/msid-63240993,width-1070,height-580,imgsize-1095835,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg
# 2026-02-24 09:22:31,018 - INFO - downloader - image #2	https://static.toiimg.com/thumb/msid-63240993,imgsize-1095835,width-400,resizemode-4/63240993.jpg
# ...

# %%
crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/fallen_pole'}
)

crawler.crawl(
    keyword='fallen electric pole after storm india',
    max_num=120
)
# Out:
# 2026-02-24 09:24:43,732 - INFO - icrawler.crawler - start crawling...
# 2026-02-24 09:24:43,734 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-24 09:24:43,737 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-24 09:24:43,741 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-24 09:24:43,742 - INFO - feeder - thread feeder-001 exit
# 2026-02-24 09:24:44,826 - INFO - parser - parsing result page https://www.bing.com/images/async?q=fallen electric pole after storm india&first=0
# 2026-02-24 09:24:45,763 - INFO - downloader - image #1	https://www.shutterstock.com/image-photo/fallen-crash-electric-pole-after-260nw-1457827109.jpg
# 2026-02-24 09:24:47,287 - INFO - downloader - image #2	https://l450v.alamy.com/450v/2bw9fx0/high-tension-electric-wires-hanging-dangerously-from-a-broken-pole-on-a-city-road-after-cyclonic-storm-amphan-struck-landfall-at-kolkata-india-2bw9fx0.jpg
# ...

# %%
crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/potholes'}
)

crawler.crawl(
    keyword='potholes road india',
    max_num=120
)
# Out:
# 2026-02-24 09:26:46,100 - INFO - icrawler.crawler - start crawling...
# 2026-02-24 09:26:46,102 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-24 09:26:46,106 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-24 09:26:46,111 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-24 09:26:46,111 - INFO - feeder - thread feeder-001 exit
# 2026-02-24 09:26:47,620 - INFO - parser - parsing result page https://www.bing.com/images/async?q=potholes road india&first=0
# 2026-02-24 09:26:48,426 - ERROR - downloader - Response status code 400, file https://media.gettyimages.com/id/1243273859/photo/mumbai-india-september-15-potholes-resurface-on-the-roads-in-the-city-after-ganpati-visarjan.jpg
# 2026-02-24 09:26:48,965 - ERROR - downloader - Response status code 400, file https://media.gettyimages.com/id/820070276/photo/mumbai-india-the-recent-heavy-spell-of-showers-has-increased-the-problem-of-commuters-as-huge.jpg
# ...

# %%
crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/road_cracks'}
)

crawler.crawl(
    keyword='cracked road surface india',
    max_num=120
)
# Out:
# 2026-02-24 09:28:19,181 - INFO - icrawler.crawler - start crawling...
# 2026-02-24 09:28:19,183 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-24 09:28:19,187 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-24 09:28:19,191 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-24 09:28:19,193 - INFO - feeder - thread feeder-001 exit
# 2026-02-24 09:28:20,279 - INFO - parser - parsing result page https://www.bing.com/images/async?q=cracked road surface india&first=0
# 2026-02-24 09:28:21,861 - INFO - downloader - image #1	https://thumbs.dreamstime.com/z/cracked-road-surface-subsidence-dangerous-road-surface-construction-old-cracked-road-surface-subsidence-dangerous-road-surface-255672567.jpg
# 2026-02-24 09:28:23,147 - INFO - downloader - image #2	https://d2gg9evh47fn9z.cloudfront.net/800px_COLOURBOX6860386.jpg
# ...

# %%
crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/road_blockage'}
)

crawler.crawl(
    keyword='road blocked by debris india',
    max_num=120
)
# Out:
# 2026-02-24 09:30:09,772 - INFO - icrawler.crawler - start crawling...
# 2026-02-24 09:30:09,775 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-02-24 09:30:09,778 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-02-24 09:30:09,783 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-02-24 09:30:09,783 - INFO - feeder - thread feeder-001 exit
# 2026-02-24 09:30:11,171 - INFO - parser - parsing result page https://www.bing.com/images/async?q=road blocked by debris india&first=0
# 2026-02-24 09:30:13,362 - INFO - downloader - image #1	https://img.freepik.com/premium-photo/road-is-blocked-by-debris-debris_1068983-26414.jpg
# 2026-02-24 09:30:14,524 - INFO - downloader - image #2	https://resize.indiatvnews.com/en/resize/newbucket/1200_-/2023/08/debris-chamoli-police-1691030488.jpg
# ...

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False

# %%
model = models.Sequential([
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.compile(
#       2     optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#       3     loss='sparse_categorical_crossentropy',
#       4     metrics=['accuracy']
#       5 )
#
# NameError: name 'model' is not defined

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 history = model.fit(
#       2     train_ds,
#       3     validation_data=val_ds,
#       4     epochs=15
#       5 )
#
# NameError: name 'model' is not defined

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.figure(figsize=(8,5))
# ----> 2 plt.plot(history.history['accuracy'], label='Train Accuracy')
#       3 plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
#       4 plt.legend()
#
# NameError: name 'history' is not defined

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# =========================
# SETTINGS
# =========================
IMG_SIZE = 224
BATCH_SIZE = 32
NUM_CLASSES = 12   # 👈 change if different

# =========================
# LOAD DATASET
# =========================
train_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset_split/train",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset_split/val",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

# Optimize performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# =========================
# DATA AUGMENTATION
# =========================
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# =========================
# BASE MODEL
# =========================
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False

# =========================
# BUILD MODEL
# =========================
model = models.Sequential([
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# =========================
# COMPILE
# =========================
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15
)

# =========================
# PLOT RESULTS
# =========================
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()

# =========================
# SAVE MODEL
# =========================
model.save("civic_issue_model.h5")
# Out:
# Found 315 files belonging to 6 classes.
# Found 80 files belonging to 6 classes.
# Epoch 1/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.1048 - loss: 3.1868 - val_accuracy: 0.1000 - val_loss: 2.8860
# Epoch 2/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 950ms/step - accuracy: 0.1460 - loss: 2.9732 - val_accuracy: 0.1625 - val_loss: 2.7774
# Epoch 3/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 850ms/step - accuracy: 0.1397 - loss: 2.8225 - val_accuracy: 0.2000 - val_loss: 2.6820
# Epoch 4/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 738ms/step - accuracy: 0.1556 - loss: 2.7430 - val_accuracy: 0.2250 - val_loss: 2.6000
# Epoch 5/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 758ms/step - accuracy: 0.1556 - loss: 2.7554 - val_accuracy: 0.2500 - val_loss: 2.5304
# Epoch 6/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 835ms/step - accuracy: 0.2095 - loss: 2.6307 - val_accuracy: 0.2500 - val_loss: 2.4752
# Epoch 7/15
# ...
